# %%
import pandas as pd
import numpy as np

# %%
mydata = ['Boat', 'Car','Bike','Truck']
myseries1 = pd.Series(mydata)

# %%
print(myseries1)
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %%
mydata = [1, 55, 43, 99]
myseries2 = pd.Series(mydata)

# %%
print(myseries2)
# Out:
# 0     1
# 1    55
# 2    43
# 3    99
# dtype: int64

# %%
#Dataframe

# %%
mydfdata = [('Boat',1), ('Car',55) ,('Bike',43),('Truck',99)]
mydf = pd.DataFrame(mydfdata, columns = ['thing','count'])
mydf
# Out:
#    thing  count
# 0   Boat      1
# 1    Car     55
# 2   Bike     43
# 3  Truck     99

# %%
(mydf['thing'])
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# Name: thing, dtype: object

# %%
type(mydf['thing'])
# Out:
# pandas.core.series.Series

# %%
mydf.dtypes
# Out:
# thing    object
# count     int64
# dtype: object

# %%
#Reading in Data

# %%
df = pd.read_csv(r"/Users/oluwafemiajibola/PythonProjects/MrBeast_youtube_stats.csv")

# %%
#inspect the data

# %%
df.head() #returns first 5 rows
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2          NaN                                            MrBeast
# 3  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  Accomplishments - Raised $20000000 To Plant 20...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2021-04-24 20:00:00+00:00  youtube#video               861   84717282.0
# 1  2021-12-18 21:00:00+00:00  youtube#video               729   32090178.0
# ...

# %%
df.tail() #returns last 5 rows
# Out:
#               id                                              title  \
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 242  Yup, another very pointless video ▻ Subscribe?...
# 243  Look at this - http://gyazo.com/8852509d2350db...
# 244  The beginning of the video is a little off top...
# 245  His channel - https://www.youtube.com/user/the...
# 246  In this video I talk about being an uber drive...
#
#                    publishTime     kind_stats  duration_seconds  viewCount  \
# 242  2015-04-26 21:26:36+00:00  youtube#video               216    16312.0
# ...

# %%
df.dtypes #describes what datatype each column is
# Out:
# id                                        object
# title                                     object
# description                               object
# publishTime                               object
# kind_stats                                object
# duration_seconds                           int64
# viewCount                                float64
# likeCount                                float64
# commentCount                             float64
# thumbnails.default.url                    object
# thumbnails.default.width                 float64
# thumbnails.default.height                float64
# thumbnails.medium.url                     object
# thumbnails.medium.width                  float64
# thumbnails.medium.height                 float64
# thumbnails.high.url                       object
# thumbnails.high.width                    float64
# thumbnails.high.height                   float64
# contentDetails.duration                   object
# ...

# %%
df.describe() #describes the numeric data in the data
# Out:
#        duration_seconds     viewCount     likeCount   commentCount  \
# count        247.000000  2.460000e+02  2.440000e+02     245.000000
# mean        1886.234818  5.084638e+07  1.610498e+06   75562.783673
# std         8642.188728  4.062672e+07  1.879529e+06   85356.537127
# min            0.000000  1.395400e+04  3.700000e+02      59.000000
# 25%          425.500000  1.406442e+07  4.348780e+05   21552.000000
# 50%          776.000000  4.904782e+07  1.358232e+06   60701.000000
# 75%          923.000000  8.125392e+07  2.294378e+06   99670.000000
# max        85686.000000  1.787632e+08  1.904943e+07  726861.000000
#
#        thumbnails.default.width  thumbnails.default.height  \
# count                     246.0                      246.0
# mean                      120.0                       90.0
# std                         0.0                        0.0
# min                       120.0                       90.0
# 25%                       120.0                       90.0
# ...

# %%
#Columns and Rows

# %%
df.head() #returns first 5 rows
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2          NaN                                            MrBeast
# 3  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  Accomplishments - Raised $20000000 To Plant 20...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2021-04-24 20:00:00+00:00  youtube#video               861   84717282.0
# 1  2021-12-18 21:00:00+00:00  youtube#video               729   32090178.0
# ...

# %%
df['viewCount'] #picking a specific column
# Out:
# 0       84717282.0
# 1       32090178.0
# 2              NaN
# 3      101745632.0
# 4       50008942.0
#           ...
# 242        16312.0
# 243        15740.0
# 244        18502.0
# 245        16627.0
# 246        18773.0
# Name: viewCount, Length: 247, dtype: float64

# %%
df.loc[4] #return a specific row(description) with particular index
# Out:
# id                                                                             cExLQ1o2pDw
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# ...

# %%
df.set_index('id') #setting the id row to be the index
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df = df.set_index('id')
df.loc['56OkH6ocYZU'] #taking a 'new' index of one of the videos and providing description for 
                     #the particular row. useful for timestamp data indexes
# Out:
# title                                      L0114R - Biblical Creeper Post for Post @L0114R
# description                              His channel - https://www.youtube.com/user/the...
# publishTime                                                      2015-05-15 16:48:54+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       109
# viewCount                                                                          16627.0
# likeCount                                                                            430.0
# commentCount                                                                         134.0
# thumbnails.default.url                      https://i.ytimg.com/vi/56OkH6ocYZU/default.jpg
# thumbnails.default.width                                                             120.0
# ...

# %%
#subsetting data

# %%
df.columns #returns all the columns of the dataset
# Out:
# Index(['title', 'description', 'publishTime', 'kind_stats', 'duration_seconds',
#        'viewCount', 'likeCount', 'commentCount', 'thumbnails.default.url',
#        'thumbnails.default.width', 'thumbnails.default.height',
#        'thumbnails.medium.url', 'thumbnails.medium.width',
#        'thumbnails.medium.height', 'thumbnails.high.url',
#        'thumbnails.high.width', 'thumbnails.high.height',
#        'contentDetails.duration', 'contentDetails.dimension',
#        'topicDetails.topicCategories', 'snippet.defaultLanguage',
#        'localizations.en.title', 'localizations.en.description',
#        'snippet.tags', 'contentDetails.contentRating.ytRating'],
#       dtype='object')

# %%
#lets say we want to keep only a subset of the above, it goes down below:

# %%
df = df[['title', 'description', 'publishTime', 'duration_seconds',
       'viewCount', 'likeCount', 'commentCount']]

# %%
df.head()
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# NaN          Accomplishments - Raised $20000000 To Plant 20...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# cExLQ1o2pDw  I didnt think he would actually rob the bank.....
#
#                            publishTime  duration_seconds    viewCount  \
# id
# TQHEJj68Jew  2021-04-24 20:00:00+00:00               861   84717282.0
# ...

# %%
#trying to know how many rows and columns we still got.

# %%
df.shape #current rows,current columns
# Out:
# (247, 7)

# %%
#Subsetting rows

# %%
#first, we are checking rows with more than 1,000,000

# %%
df['viewCount'] > 1_000_000 #returns ID/Index of rows with more than 1,000,000 viewCount
# Out:
# id
# TQHEJj68Jew     True
# 00NgUctWoLQ     True
# NaN            False
# ayXxwJJId_c     True
# cExLQ1o2pDw     True
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
#subsetting using loc
df_subset1 = df.loc[df['viewCount'] > 1_000_000] #displays all rows with more than 10000000 viewcount
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
#subsetting using query
df.query('viewCount > 1000000')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 #subsetting using query
# ----> 2 df.query('viewCount > 1000000')
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv(r"/Users/oluwafemiajibola/PythonProjects/MrBeast_youtube_stats.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df = pd.read_csv(r"/Users/oluwafemiajibola/PythonProjects/MrBeast_youtube_stats.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/Users/oluwafemiajibola/PythonProjects/MrBeast_youtube_stats.csv")

# %%
df.query('viewCount > 1000000')
# Out:
#               id                                              title  \
# 0    TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1    00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 3    ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4    cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# 5    GLoeAJUcz38                 Press This Button To Win $100,000!
# ..           ...                                                ...
# 225  xWcldHxHFpo                              I Counted To 100,000!
# 226  mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 230  9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 231  2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# 232  bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# ...

# %%
df_subset2 = df.query('viewCount > 1000000')

# %%
df
# Out:
#               id                                              title  \
# 0    TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1    00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2            NaN                                            MrBeast
# 3    ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4    cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ..           ...                                                ...
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# ...

# %%
df['viewCount'].isna() #returns which rows have nan(null) values as True or False #IGNORE
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Name: viewCount, Length: 247, dtype: bool

# %%
df.loc[~df['viewCount'].isna()] #with the ~ sign, it displays only  rows with nan (i think) #IGNORE
# Out:
#               id                                              title  \
# 0    TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1    00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 3    ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4    cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# 5    GLoeAJUcz38                 Press This Button To Win $100,000!
# ..           ...                                                ...
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# ...

# %%
df = df[['title', 'description', 'publishTime', 'duration_seconds',
       'viewCount', 'likeCount', 'commentCount']]

# %%
df.loc[~df['viewCount'].isna()] #returns only rows that dont have nan(null) values cuz of the ~
                                #essentially removes the null value column
# Out:
#                                                  title  \
# 0                 I Got Hunted By A Real Bounty Hunter
# 1                     Extreme $1,000,000 Hide And Seek
# 3    I Bought The World&#39;s Largest Mystery Box! ...
# 4                      First To Rob Bank Wins $100,000
# 5                   Press This Button To Win $100,000!
# ..                                                 ...
# 242                         Remember When COD Was Fun?
# 243                  Insane Gun Sync - 7 Hours To Make
# 244   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245    L0114R - Biblical Creeper Post for Post @L0114R
# 246  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# 1    I didn't expect that to happen at the end I wa...
# 3    I cant believe I spent over $500000 on mystery...
# 4    I didnt think he would actually rob the bank.....
# ...

# %%
#Casting dtypes

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount           float64
# likeCount           float64
# commentCount        float64
# dtype: object

# %%
df['viewCount'].astype('int') #casting the viewCount column as an int (converting it to int)

# %%
df['viewCount'] = df['viewCount'].astype('int') #rewrites it in the dataframe
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df['viewCount'] = df['viewCount'].astype('int')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df = df.loc[~df['likeCount'].isna()]

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount           float64
# likeCount           float64
# commentCount        float64
# dtype: object

# %%
df['likeCount'] = df['likeCount'].astype('int')

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount           float64
# likeCount             int64
# commentCount        float64
# dtype: object

# %%
df = df.loc[~df['viewCount'].isna()] #removing null values

# %%
df['viewCount'] = df['viewCount'].astype('int') #casting viewCount column as int

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount             int64
# likeCount             int64
# commentCount        float64
# dtype: object

# %%
df['publishTime'] = pd.to_datetime(df['publishTime'])

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int64
# likeCount                         int64
# commentCount                    float64
# dtype: object

# %%
df['likeCount'].astype('str')
# Out:
# 0      2876493
# 1      2125183
# 3      3110824
# 4      2359606
# 5      2762425
#         ...
# 242        574
# 243        637
# 244        508
# 245        430
# 246        370
# Name: likeCount, Length: 244, dtype: object

# %%
df['likeCount'] = pd.to_numeric(df['likeCount'].astype('str')) #better way of casting to int or float as pd
                                                               #chooses itself whether the data is int or float (pd.to_numeric)

# %%
df['likeCount']
# Out:
# 0      2876493
# 1      2125183
# 3      3110824
# 4      2359606
# 5      2762425
#         ...
# 242        574
# 243        637
# 244        508
# 245        430
# 246        370
# Name: likeCount, Length: 244, dtype: int64

# %%
#creating new column

# %%
df.head()
# Out:
#                                                title  \
# 0               I Got Hunted By A Real Bounty Hunter
# 1                   Extreme $1,000,000 Hide And Seek
# 3  I Bought The World&#39;s Largest Mystery Box! ...
# 4                    First To Rob Bank Wins $100,000
# 5                 Press This Button To Win $100,000!
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
# 5  Push the red subscribe button and you could al...
#
#                 publishTime  duration_seconds  viewCount  likeCount  \
# 0 2021-04-24 20:00:00+00:00               861    2876493    2876493
# 1 2021-12-18 21:00:00+00:00               729    2125183    2125183
# 3 2021-04-03 20:00:01+00:00               709    3110824    3110824
# ...

# %%
#Creating New Column

# %%
#for instance, creating from existing column: let's say we want to find the ratio of viewCount to likeCount

# %%
df['likeCount'] / df['viewCount'] #this will give us a new panda series
                                  #my values arent valueing cuz i disconnected the server at a point but if one is to 
                                  #to create a new column, it would be this way
                                  #ouch! somewhere along the line, i had rewritten viewCount to likeCount so they are the same now
# Out:
# 0      1.0
# 1      1.0
# 3      1.0
# 4      1.0
# 5      1.0
#       ...
# 242    1.0
# 243    1.0
# 244    1.0
# 245    1.0
# 246    1.0
# Length: 244, dtype: float64

# %%
df['like_to_view_ratio'] = df['likeCount'] / df['viewCount']

# %%
df.head()
# Out:
#                                                title  \
# 0               I Got Hunted By A Real Bounty Hunter
# 1                   Extreme $1,000,000 Hide And Seek
# 3  I Bought The World&#39;s Largest Mystery Box! ...
# 4                    First To Rob Bank Wins $100,000
# 5                 Press This Button To Win $100,000!
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
# 5  Push the red subscribe button and you could al...
#
#                 publishTime  duration_seconds  viewCount  likeCount  \
# 0 2021-04-24 20:00:00+00:00               861    2876493    2876493
# 1 2021-12-18 21:00:00+00:00               729    2125183    2125183
# 3 2021-04-03 20:00:01+00:00               709    3110824    3110824
# ...

# %%
#adding new row
#the easiest way to do this is to concatenate 2 dfs ontop of each other

# %%
df_to_append = df.tail(1) #this takes the last row and puts it in the df_to_append df right

# %%
pd.concat([df, df_to_append]) #pd.concat() takes 2 argument, the original list you want to append to; the object you want to append
# Out:
#                                                  title  \
# 0                 I Got Hunted By A Real Bounty Hunter
# 1                     Extreme $1,000,000 Hide And Seek
# 3    I Bought The World&#39;s Largest Mystery Box! ...
# 4                      First To Rob Bank Wins $100,000
# 5                   Press This Button To Win $100,000!
# ..                                                 ...
# 243                  Insane Gun Sync - 7 Hours To Make
# 244   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245    L0114R - Biblical Creeper Post for Post @L0114R
# 246  How Much Money Do You Make As An Uber Driver??...
# 246  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# 1    I didn't expect that to happen at the end I wa...
# 3    I cant believe I spent over $500000 on mystery...
# 4    I didnt think he would actually rob the bank.....
# ...

# %%
df_concat = pd.concat([df, df_to_append])

# %%
#Plot Examples

# %%
df['viewCount'].plot(kind = 'hist', bins =50, 
                     title = 'Distribution of View Count', figsize = (15,5)) #for plotting histograms
# Out:
# <AxesSubplot:title={'center':'Distribution of View Count'}, ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='viewCount', y='likeCount', 
        title = 'View vs Like Count', figsize = (15,5)) #for Scattered plots
# Out:
# <AxesSubplot:title={'center':'View vs Like Count'}, xlabel='viewCount', ylabel='likeCount'>

# %%
#save our output

# %%
df.to_csv('processed_data.csv')
#df.to_csv('processed_data.csv', index = False) #if you dont wanna save the index
